# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
train= pd.read_csv('./DataSets/Machine_Experiments/train.csv')
exp1=pd.read_csv('./DataSets\Machine_Experiments\experiment_01.csv')
exp2=pd.read_csv('./DataSets\Machine_Experiments\experiment_02.csv')
exp3=pd.read_csv('./DataSets\Machine_Experiments\experiment_03.csv')
exp4=pd.read_csv('./DataSets\Machine_Experiments\experiment_04.csv')
exp5=pd.read_csv('./DataSets\Machine_Experiments\experiment_05.csv')
exp6=pd.read_csv('./DataSets\Machine_Experiments\experiment_06.csv')
exp7=pd.read_csv('./DataSets\Machine_Experiments\experiment_07.csv')
exp8=pd.read_csv('./DataSets\Machine_Experiments\experiment_08.csv')
exp9=pd.read_csv('./DataSets\Machine_Experiments\experiment_09.csv')
exp10=pd.read_csv('./DataSets\Machine_Experiments\experiment_10.csv')
exp11=pd.read_csv('./DataSets\Machine_Experiments\experiment_11.csv')
exp12=pd.read_csv('./DataSets\Machine_Experiments\experiment_12.csv')
exp13=pd.read_csv('./DataSets\Machine_Experiments\experiment_13.csv')
exp14=pd.read_csv('./DataSets\Machine_Experiments\experiment_14.csv')
exp15=pd.read_csv('./DataSets\Machine_Experiments\experiment_15.csv')
exp16=pd.read_csv('./DataSets\Machine_Experiments\experiment_16.csv')
exp17=pd.read_csv('./DataSets\Machine_Experiments\experiment_17.csv')
exp18=pd.read_csv('./DataSets\Machine_Experiments\experiment_18.csv')

# %%
first = train.iloc[0].to_dict()
exp1 = exp1.assign(**first)
exp1 = exp1.drop(columns= ['No'])

exp1.shape
# Out:
#       X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# 0                 198.0              0.000                   0.00
# 1                 198.0            -10.800                -350.00
# 2                 196.0            -17.800                  -6.25
# 3                 194.0            -18.000                   0.00
# 4                 193.0            -17.900                 -18.80
# ...                 ...                ...                    ...
# 1050              141.0              0.175                  87.50
# 1051              141.0             -0.150                 -87.50
# 1052              141.0             -0.175                 -87.50
# 1053              141.0              0.150                  87.50
# 1054              141.0              0.175                  93.70
#
#       X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# 0                  198.0                 0.0                0.000000
# ...

# %%
exp1.shape
# Out:
# (1055, 54)

# %%
# Add the colomn to all the data frams at ones 
for i in range(1, 18):
    
    var_name = f"exp{i+1}" 
    cascaded_data = train.iloc[i].to_dict()
    
    
    if var_name in globals():
        df = globals()[var_name]
        df = df.assign(**cascaded_data).drop(columns=['No'])
        globals()[var_name] = df

# %%
# Create a list of all your exp dataframes
all_exps = [globals()[f"exp{i}"] for i in range(1, 19) if f"exp{i}" in globals()]

# Concatenate them all into one big table
master_df = pd.concat(all_exps, axis=0, ignore_index=True)

# %%
master_df.shape
# Out:
# (25286, 54)

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25286 entries, 0 to 25285
# Data columns (total 54 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   X1_ActualPosition          25286 non-null  float64
#  1   X1_ActualVelocity          25286 non-null  float64
#  2   X1_ActualAcceleration      25286 non-null  float64
#  3   X1_CommandPosition         25286 non-null  float64
#  4   X1_CommandVelocity         25286 non-null  float64
#  5   X1_CommandAcceleration     25286 non-null  float64
#  6   X1_CurrentFeedback         25286 non-null  float64
#  7   X1_DCBusVoltage            25286 non-null  float64
#  8   X1_OutputCurrent           25286 non-null  float64
#  9   X1_OutputVoltage           25286 non-null  float64
#  10  X1_OutputPower             25286 non-null  float64
#  11  Y1_ActualPosition          25286 non-null  float64
#  12  Y1_ActualVelocity          25286 non-null  float64
# ...

# %%
master_df['passed_visual_inspection'].describe()
# Out:
# count     23125
# unique        2
# top         yes
# freq      19183
# Name: passed_visual_inspection, dtype: object

# %%
master_df.isna().sum()
# Out:
# X1_ActualPosition               0
# X1_ActualVelocity               0
# X1_ActualAcceleration           0
# X1_CommandPosition              0
# X1_CommandVelocity              0
# X1_CommandAcceleration          0
# X1_CurrentFeedback              0
# X1_DCBusVoltage                 0
# X1_OutputCurrent                0
# X1_OutputVoltage                0
# X1_OutputPower                  0
# Y1_ActualPosition               0
# Y1_ActualVelocity               0
# Y1_ActualAcceleration           0
# Y1_CommandPosition              0
# Y1_CommandVelocity              0
# Y1_CommandAcceleration          0
# Y1_CurrentFeedback              0
# Y1_DCBusVoltage                 0
# Y1_OutputCurrent                0
# Y1_OutputVoltage                0
# Y1_OutputPower                  0
# Z1_ActualPosition               0
# Z1_ActualVelocity               0
# Z1_ActualAcceleration           0
# Z1_CommandPosition              0
# Z1_CommandVelocity              0
# ...

# %%
master_df.to_csv('./DataSets/MergedData.csv')
